# %%
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
mnist=tf.keras.datasets.mnist
z=mnist.load_data()
(x_train,y_train), (x_test,y_test)=z
print(x_test.shape)
print(y_test.shape)
# Out:
# (10000, 28, 28)
# (10000,)

# %%
plt.imshow(x_train[9])
plt.show()

# %%
# Normalize the TRAINING DATA

x_train=tf.keras.utils.normalize(x_train,axis=1).reshape(x_train.shape[0], -1)
x_test=tf.keras.utils.normalize(x_test,axis=1).reshape(x_test.shape[0], -1)

# Build a Sequential Model
model=tf.keras.models.Sequential()

# Add an input layer
model.add(tf.keras.layers.Flatten())

# Add an Hidden layer 
model.add(tf.keras.layers.Dense(128,activation=tf.nn.relu))

# Add a second Hidden Layer
model.add(tf.keras.layers.Dense(128,activation=tf.nn.relu))

# Get the Output layer
model.add(tf.keras.layers.Dense(10,activation=tf.nn.softmax))

# Compile our Model
model.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# Train our Model
model.fit(x_train,y_train,epochs=3)
# Out:
# Train on 60000 samples
# Epoch 1/3
# 60000/60000 [==============================] - 12s 202us/sample - loss: 0.3386 - accuracy: 0.9041
# Epoch 2/3
# 60000/60000 [==============================] - 6s 105us/sample - loss: 0.1452 - accuracy: 0.9566
# Epoch 3/3
# 60000/60000 [==============================] - 6s 105us/sample - loss: 0.0980 - accuracy: 0.9697

# %%
val_loss,val_acc=model.evaluate(x_test, y_test)
print(val_loss,val_acc)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# 0.37577238525803164 0.9535

# %%
pred=model.predict([x_test])
import numpy as np
print(np.argmax(pred[5]))
# Out:
# 1

# %%
plt.imshow(x_test[5], cmap=plt.cm.binary)
